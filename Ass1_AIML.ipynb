# %% [markdown]
# **POLADAS GEETANJALI**

# %% [markdown]
# **21BCE9114**

# %%
#importing libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Task - 1
#
# Create a pandas dataframe (dataframe name as 'df') (10 observations 5 features)

# %%
df=pd.read_csv("mtcars.csv")
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.tail()
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %% [markdown]
# Task - 2
#
# Check the info of 'df'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# Task - 3
#
# Check the descriptive statistics of 'df'

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# Task - 4
#
# Check the 4th index observation 'loc' slicing operator

# %%
df.loc[3:3 , :]
# Out:
#             model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 3  Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
#
#    carb
# 3     1

# %% [markdown]
# Task - 5
#
# Check the null values in 'df'

# %%
df.isnull().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %% [markdown]
# **Assignment - 1**

# %% [markdown]
# Task - 1
#
# Create a pandas dataframe (named as 'df') with numpy random values (4 features 4 observations)

# %%
data = np.random.rand(4, 4)
df = pd.DataFrame(data, columns=['f1', 'f2', 'f3', 'f4'])
df
# Out:
#          f1        f2        f3        f4
# 0  0.824180  0.282191  0.612735  0.694341
# 1  0.178369  0.443578  0.233097  0.441842
# 2  0.069581  0.963611  0.577158  0.598037
# 3  0.680758  0.470973  0.707971  0.063156

# %% [markdown]
# Task - 2
#
# Rename the Task - 1 'df' dataframe column names to 'Feat1', 'Feat2', 'Feat3' & 'Feat4'

# %%
new_col_names = [ 'Feat1' , 'Feat2' , 'Feat3' , 'Feat4' ]
df.columns = new_col_names
df
# Out:
#       Feat1     Feat2     Feat3     Feat4
# 0  0.824180  0.282191  0.612735  0.694341
# 1  0.178369  0.443578  0.233097  0.441842
# 2  0.069581  0.963611  0.577158  0.598037
# 3  0.680758  0.470973  0.707971  0.063156

# %% [markdown]
# Task - 3
#
# Find the descriptive statistics of the 'df' dataframe

# %%
df.describe()
# Out:
#           Feat1     Feat2     Feat3     Feat4
# count  4.000000  4.000000  4.000000  4.000000
# mean   0.438222  0.540088  0.532740  0.449344
# std    0.370228  0.294377  0.207255  0.277687
# min    0.069581  0.282191  0.233097  0.063156
# 25%    0.151172  0.403231  0.491143  0.347170
# 50%    0.429564  0.457276  0.594946  0.519939
# 75%    0.716613  0.594133  0.636544  0.622113
# max    0.824180  0.963611  0.707971  0.694341

# %% [markdown]
# Task - 4
#
# Check for the null values in 'df' and find the data type of the columns

# %%
df.isnull().any()
# Out:
# Feat1    False
# Feat2    False
# Feat3    False
# Feat4    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Feat1   4 non-null      float64
#  1   Feat2   4 non-null      float64
#  2   Feat3   4 non-null      float64
#  3   Feat4   4 non-null      float64
# dtypes: float64(4)
# memory usage: 256.0 bytes

# %% [markdown]
# Task - 5
#
# Display the 'Feat3' & 'Feat4' columns with location method and index location method.

# %%
df.loc[: , 'Feat3' : 'Feat4']
# Out:
#       Feat3     Feat4
# 0  0.612735  0.694341
# 1  0.233097  0.441842
# 2  0.577158  0.598037
# 3  0.707971  0.063156

# %%
df.iloc[: , 2:4]
# Out:
#       Feat3     Feat4
# 0  0.612735  0.694341
# 1  0.233097  0.441842
# 2  0.577158  0.598037
# 3  0.707971  0.063156
